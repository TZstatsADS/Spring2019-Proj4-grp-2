# %%
import numpy as np
import pandas as pd

# %%
ground_truth = open("C:/Users/Zixiao/Documents/GitHub/Spring2019-Proj4-grp-2/data/ground_truth/group1_00000005.txt", "r")

# %%
lines = ground_truth.read().split('\n')

# %%
lines
# Out:
# ['EXHIBIT D',
#  'STAFF REPORT',
#  'Ma rch 1972',
#  'by',
#  'William J. Driver',
#  'CONGRESSIONAL ACTION...',
#  '...involving portions of the Foreign Trade and Investment Act of',
#  "'1972 suddenly loomed as a possibility last week when it was learned",
#  'that the AFL-CIO planned to attempt attaching Titles VI and VII of',
#  "that proposed Act to the Administration's gold legislation.",
#  'Through agreement with House Ways and Means Committee Chairman',
#  'Wilbur D. Mills (D.-Ark.), the House Banking and Currency Committee',
#  'has been given jurisdiction over Titles VI and VII of the so-called',
#  'The latter committee scheduled gold bill hearings March 1-6 and,',
#  'immediately afterward, is expected to begin executive session markÂ\xad',
#  'Rapid enactment is anticipated.',
#  "Organized labor's position, to be presented the last day of hearÂ\xad",
#  'ings, is that dollar devaluation in itself does not provide adequate',
# ...

# %%
tesseract = open("C:/Users/Zixiao/Documents/GitHub/Spring2019-Proj4-grp-2/data/tesseract/group1_00000005.txt", "r",encoding="utf8")

# %%
tes_lines = tesseract.read().split("\n")

# %%
tes_list = list()
for element in tes_lines:
    element  = element.split(" ")
    tes_list.append(element)

# %%
tes_lines
# Out:
# ['xansm u',
#  '5 REPORT',
#  'Ma rah',
#  'by',
#  'Willlam J. Drlver',
#  'CONGRESSIONAL ACTION. ..',
#  '...1nvolv1ng portlons of t orelgn Trade and Investment Act of',
#  'V1972 suddenly loomed as a pass 1ty last week when 1: was learned',
#  'that the AFL’CID planned to attempt cmng Tltles v1 and VII of',
#  "that proposed Act to the Admlnlstratlon's d leglslatlon.",
#  'Through agreement mm House Ways and Means Co tee Chalrman',
#  'Wllbur u. M1115 (DrArk—M the House Banklng and Cu Cy Commlttee',
#  'has been given jurlsdlctlon over Tltles v1 and VII of t *called',
#  'The latter commlttee scheduled gold mu hearlngs March 175 a',
#  'unmedlately afterward, 1: expected to begln executlve sesslon mar',
#  'Rapld enactment 15 antlclpated.',
#  "Drganlzed Labor's posltlon, m be presented the last day of heari",
#  'lngs, 15 that dollar devaluatlon 1n 1tself does not provlde adequate',
#  'remedles and that the stronger measures embodled 1n the Hartke43urke',
#  'mm are needed.',
# ...

# %%
tes_list
# Out:
# [['xansm', 'u'],
#  ['5', 'REPORT'],
#  ['Ma', 'rah'],
#  ['by'],
#  ['Willlam', 'J.', 'Drlver'],
#  ['CONGRESSIONAL', 'ACTION.', '..'],
#  ['...1nvolv1ng',
#   'portlons',
#   'of',
#   't',
#   'orelgn',
#   'Trade',
#   'and',
#   'Investment',
#   'Act',
#   'of'],
#  ['V1972',
#   'suddenly',
#   'loomed',
#   'as',
#   'a',
#   'pass',
#   '1ty',
#   'last',
#   'week',
#   'when',
#   '1:',
#   'was',
#   'learned'],
#  ['that',
#   'the',
#   'AFL’CID',
#   'planned',
#   'to',
#   'attempt',
#   'cmng',
#   'Tltles',
#   'v1',
#   'and',
#   'VII',
#   'of'],
#  ['that',
#   'proposed',
#   'Act',
#   'to',
#   'the',
#   "Admlnlstratlon's",
#   'd',
#   'leglslatlon.'],
#  ['Through',
#   'agreement',
#   'mm',
#   'House',
#   'Ways',
#   'and',
#   'Means',
#   'Co',
#   'tee',
#   'Chalrman'],
#  ['Wllbur',
#   'u.',
#   'M1115',
#   '(DrArk—M',
#   'the',
#   'House',
#   'Banklng',
#   'and',
#   'Cu',
#   'Cy',
#   'Commlttee'],
#  ['has',
#   'been',
#   'given',
# ...

# %%
truth_list = list()
for element in lines:
    element  = element.split(" ")
    truth_list.append(element)

# %%
truth_list
# Out:
# [['EXHIBIT', 'D'],
#  ['STAFF', 'REPORT'],
#  ['Ma', 'rch', '1972'],
#  ['by'],
#  ['William', 'J.', 'Driver'],
#  ['CONGRESSIONAL', 'ACTION...'],
#  ['...involving',
#   'portions',
#   'of',
#   'the',
#   'Foreign',
#   'Trade',
#   'and',
#   'Investment',
#   'Act',
#   'of'],
#  ["'1972",
#   'suddenly',
#   'loomed',
#   'as',
#   'a',
#   'possibility',
#   'last',
#   'week',
#   'when',
#   'it',
#   'was',
#   'learned'],
#  ['that',
#   'the',
#   'AFL-CIO',
#   'planned',
#   'to',
#   'attempt',
#   'attaching',
#   'Titles',
#   'VI',
#   'and',
#   'VII',
#   'of'],
#  ['that',
#   'proposed',
#   'Act',
#   'to',
#   'the',
#   "Administration's",
#   'gold',
#   'legislation.'],
#  ['Through',
#   'agreement',
#   'with',
#   'House',
#   'Ways',
#   'and',
#   'Means',
#   'Committee',
#   'Chairman'],
#  ['Wilbur',
#   'D.',
#   'Mills',
#   '(D.-Ark.),',
#   'the',
#   'House',
#   'Banking',
#   'and',
#   'Currency',
#   'Committee'],
#  ['has',
#   'been',
# ...

# %%
len(truth_list)
# Out:
# 249

# %%
len(tes_list)
# Out:
# 249
